# %%
# Exploratory Data Analysis: Histograms and KDE

import pandas as pd
import matplotlib.pyplot as plt

# Load cleaned data
df = pd.read_csv("energy_cleaned.csv")

# Histogram
df["%Renewable"].plot(kind="hist", bins=8, edgecolor="black")
plt.title("Histogram of % Renewable Energy")
plt.xlabel("% Renewable")
plt.grid(True)
plt.show()

# KDE plot (requires scipy)
df["%Renewable"].plot(kind="density", linewidth=2)
plt.title("Density Plot of % Renewable Energy")
plt.xlabel("% Renewable")
plt.grid(True)
plt.show()

# KDE by Region (optional)
if "Region" in df.columns:
    df.groupby("Region")["%Renewable"].plot(kind="density", legend=True)
    plt.title("Density Plot by Region")
    plt.xlabel("% Renewable")
    plt.grid(True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 26
#      24 # KDE by Region (optional)
#      25 if "Region" in df.columns:
# ---> 26     df.groupby("Region")["%Renewable"].plot(kind="density", legend=True)
#      27     plt.title("Density Plot by Region")
#      28     plt.xlabel("% Renewable")
#
# File c:\Users\micha\OneDrive\Desktop\jupyter\CST184-Data-Analysis-and-Visualization\CST184_Weekly_Activities\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:743, in GroupByPlot.__call__(self, *args, **kwargs)
#     740     return self.plot(*args, **kwargs)
#     742 f.__name__ = "plot"
# --> 743 return self._groupby._python_apply_general(f, self._groupby._selected_obj)
#
# File c:\Users\micha\OneDrive\Desktop\jupyter\CST184-Data-Analysis-and-Visualization\CST184_Weekly_Activities\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1885, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1850 @final
#    1851 def _python_apply_general(
#    1852     self,
#    (...)   1857     is_agg: bool = False,
#    1858 ) -> NDFrameT:
#    1859     """
#    1860     Apply function f in python space
#    1861
#    (...)   1883         data after applying f
#    1884     """
# -> 1885     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1886     if not_indexed_same is None:
#    1887         not_indexed_same = mutated
#
# File c:\Users\micha\OneDrive\Desktop\jupyter\CST184-Data-Analysis-and-Visualization\CST184_Weekly_Activities\.venv\Lib\site-packages\pandas\core\groupby\ops.py:919, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     917 # group might be modified
#     918 group_axes = group.axes
# --> 919 res = f(group)
#     920 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     921     mutated = True
#
# File c:\Users\micha\OneDrive\Desktop\jupyter\CST184-Data-Analysis-and-Visualization\CST184_Weekly_Activities\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:740, in GroupByPlot.__call__.<locals>.f(self)
#     739 def f(self):
# --> 740     return self.plot(*args, **kwargs)
#
# File c:\Users\micha\OneDrive\Desktop\jupyter\CST184-Data-Analysis-and-Visualization\CST184_Weekly_Activities\.venv\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\micha\OneDrive\Desktop\jupyter\CST184-Data-Analysis-and-Visualization\CST184_Weekly_Activities\.venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\micha\OneDrive\Desktop\jupyter\CST184-Data-Analysis-and-Visualization\CST184_Weekly_Activities\.venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\Users\micha\OneDrive\Desktop\jupyter\CST184-Data-Analysis-and-Visualization\CST184_Weekly_Activities\.venv\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:168, in HistPlot._make_plot(self, fig)
#     164     kwds["weights"] = type(self)._get_column_weights(self.weights, i, y)
#     166 y = reformat_hist_y_given_by(y, self.by)
# --> 168 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     170 # when by is applied, show title for subplots to know which group it is
#     171 if self.by is not None:
#
# File c:\Users\micha\OneDrive\Desktop\jupyter\CST184-Data-Analysis-and-Visualization\CST184_Weekly_Activities\.venv\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:279, in KdePlot._plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     276 from scipy.stats import gaussian_kde
#     278 y = remove_na_arraylike(y)
# --> 279 gkde = gaussian_kde(y, bw_method=bw_method)
#     281 y = gkde.evaluate(ind)
#     282 lines = MPLPlot._plot(ax, ind, y, style=style, **kwds)
#
# File c:\Users\micha\OneDrive\Desktop\jupyter\CST184-Data-Analysis-and-Visualization\CST184_Weekly_Activities\.venv\Lib\site-packages\scipy\stats\_kde.py:202, in gaussian_kde.__init__(self, dataset, bw_method, weights)
#     200 self.dataset = atleast_2d(asarray(dataset))
#     201 if not self.dataset.size > 1:
# --> 202     raise ValueError("`dataset` input should have multiple elements.")
#     204 self.d, self.n = self.dataset.shape
#     206 if weights is not None:
#
# ValueError: `dataset` input should have multiple elements.
