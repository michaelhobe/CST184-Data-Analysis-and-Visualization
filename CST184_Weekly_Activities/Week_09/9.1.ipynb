# %%
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into 'C:/Users/micha/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\micha\AppData\Local\Temp\RtmpMHxCYV\downloaded_packages

# %%
# Create binomial distribution data
n <- 10    # number of trials
p <- 0.4    # probability of success

binom_df <- data.frame(
  successes = 0:n,
  probability = dbinom(0:n, size = n, prob = p)
)

# Plot the distribution
ggplot(binom_df, aes(x = successes, y = probability)) +
  geom_bar(stat = "identity", fill = "steelblue") +
  labs(
    title = "Binomial Distribution (n = 10, p = 0.6)",
    x = "Number of Successes",
    y = "Probability"
  ) +
  theme_minimal()
# Out:
# plot without title

# %%
# Create Poisson distribution data
lambda <- 4

poisson_df <- data.frame(
  events = 0:30,
  probability = dpois(0:30, lambda = lambda)
)

# Plot the distribution
ggplot(poisson_df, aes(x = events, y = probability)) +
  geom_bar(stat = "identity", fill = "firebrick") +
  labs(
    title = "Poisson Distribution (λ = 4)",
    x = "Number of Events",
    y = "Probability"
  ) +
  theme_minimal()
#had to change value in both probability and events
# Out:
# plot without title
